# %%
# !nvidia-smi
# Out:
# Sat Jun 13 15:21:15 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   78C    P0             77W /   70W |     631MiB /  15360MiB |     81%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/ngocbao220/IM-object-detection.git
# Out:
# Cloning into 'IM-object-detection'...
# remote: Enumerating objects: 717, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (204/204), done.
# remote: Total 717 (delta 132), reused 264 (delta 79), pack-reused 395 (from 1)
# Receiving objects: 100% (717/717), 52.37 MiB | 5.45 MiB/s, done.
# Resolving deltas: 100% (353/353), done.

# %%
# %cd IM-object-detection
# Out:
# /kaggle/working/IM-object-detection

# %%
# !git checkout using-torchvision
# Out:
# Branch 'using-torchvision' set up to track remote branch 'using-torchvision' from 'origin'.
# Switched to a new branch 'using-torchvision'

# %%
# !bash download.sh --dataset
# Out:
# ============ Download Kaggle Dataset ============
# dataset: ngocbaotrinhtuan/object-detection-public
# target: /kaggle/working/IM-object-detection
# ...
# Dataset URL: https://www.kaggle.com/datasets/ngocbaotrinhtuan/object-detection-public
# License(s): CC0-1.0
# ...
# 100%|███████████████████████████████████████| 2.09G/2.09G [00:20<00:00, 107MB/s]
#
# Could not find public/ after dataset download under /kaggle/working/IM-object-detection/.kaggle_download

# %%
mv /kaggle/working/IM-object-detection/.kaggle_download /kaggle/working/IM-object-detection/public

# %%
import wandb
wandb.init()
wandb.log("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")
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#   2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#   ········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ngocbaotrinhtuan (ngocbaotrinhtuan-vietnam-national-university-hanoi) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.1
# ...

# %%
# !bash scripts/train_retina.sh
# Out:
# ========== Training Session ==========
# Started: 20260612-033207
# Run name: retina-50-512x768
# Device: cuda:0
# CUDA: Tesla T4 (14.56 GB)
# Torch: 2.10.0+cu128
# Classes: person, car, dog, cat, chair
# Train dataset: 7500 images, 10642 boxes, 2500 empty images
# Val dataset: 1500 images, 2021 boxes, 500 empty images
# Train class counts: {'dog': 1028, 'person': 5829, 'chair': 1613, 'cat': 833, 'car': 1339}
# Val class counts: {'dog': 206, 'chair': 282, 'person': 1074, 'car': 283, 'cat': 176}
# Resume: disabled
# Sampling: disabled
# Model: retina resnet50 (31,409,947/31,635,291 trainable/total params)
# Hyperparameters
# ├── Training
# │   ├── epochs             : 100
# │   ├── batch_size         : 4
# │   ├── num_workers        : 4
# │   ├── augmentation       : False
# │   ├── flip_probability   : 0.5
# │   ├── color_probability  : 0.3
# │   ├── grayscale_prob     : 0.03
# │   ├── scale_jitter_prob  : 0.4
# │   ├── scale_jitter_range : [0.85, 1.2]
# ...
