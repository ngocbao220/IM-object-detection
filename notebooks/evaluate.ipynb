# %%
# !git clone https://github.com/ngocbao220/IM-object-detection.git
# Out:
# Cloning into 'IM-object-detection'...
# remote: Enumerating objects: 775, done.
# remote: Counting objects: 100% (380/380), done.
# remote: Compressing objects: 100% (249/249), done.
# remote: Total 775 (delta 171), reused 295 (delta 92), pack-reused 395 (from 1)
# Receiving objects: 100% (775/775), 52.39 MiB | 4.71 MiB/s, done.
# Resolving deltas: 100% (392/392), done.

# %%
# %cd IM-object-detection
# Out:
# /kaggle/working/IM-object-detection/IM-object-detection

# %%
# !git checkout retina-hgnetv2-b4-fpn
# Out:
# Branch 'retina-hgnetv2-b4-fpn' set up to track remote branch 'retina-hgnetv2-b4-fpn' from 'origin'.
# Switched to a new branch 'retina-hgnetv2-b4-fpn'

# %%
# !bash download.sh --dataset
# Out:
# ============ Download Kaggle Dataset ============
# dataset: ngocbaotrinhtuan/object-detection-public
# target: /kaggle/working/IM-object-detection/IM-object-detection
# =================================================
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.1), please consider upgrading to the latest version (2.0.2)
# Dataset URL: https://www.kaggle.com/datasets/ngocbaotrinhtuan/object-detection-public
# License(s): CC0-1.0
# Downloading object-detection-public.zip to /kaggle/working/IM-object-detection/IM-object-detection/.kaggle_download
# 100%|███████████████████████████████████████| 2.09G/2.09G [00:12<00:00, 173MB/s]
#
# Could not find public/ after dataset download under /kaggle/working/IM-object-detection/IM-object-detection/.kaggle_download

# %%
# !mv .kaggle_download public

# %%
# !git pull

# %%
model_name = "hgnet_ablation-retina-retina-hgnetv2_b4-h4_best_aug_sqrt_class_weight"

# %%
# !python predict.py \
    --image_dir ./public/val/images \
    --output val_predictions.json \
    --model_name $model_name
# Out:
# Checkpoint not found; downloading checkpoint from Hugging Face...
# ============ Download Hugging Face Model ============
# repo_id: ngocbao05/object-detection-checkpoints
# path_in_repo: hgnet_ablation-retina-retina-hgnetv2_b4-h4_best_aug_sqrt_class_weight
# revision: main
# target: /kaggle/working/IM-object-detection/IM-object-detection/saved_results/hgnet_ablation-retina-retina-hgnetv2_b4-h4_best_aug_sqrt_class_weight/checkpoints
# =====================================================
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...):   0%|             | 0.00/173M [00:00<?, ?B/s]Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading (incomplete total...):   0%|   | 448/346M [00:00<47:41:46, 2.01kB/s]
# Downloading (incomplete total...):  69%|████▏ | 240M/346M [00:03<00:00, 108MB/s]
# Downloading (incomplete total...): 100%|██████| 346M/346M [00:03<00:00, 129MB/s]
# Fetching 4 files: 100%|███████████████████████████| 4/4 [00:03<00:00,  1.00it/s]
# Download complete: 100%|██████████████████████| 346M/346M [00:03<00:00, 129MB/s]Downloaded ngocbao05/object-detection-checkpoints/hgnet_ablation-retina-retina-hgnetv2_b4-h4_best_aug_sqrt_class_weight to /kaggle/working/IM-object-detection/IM-object-detection/saved_results/.hf_model_download/hgnet_ablation-retina-retina-hgnetv2_b4-h4_best_aug_sqrt_class_weight
# Download complete: 100%|█████████████████████| 346M/346M [00:04<00:00, 86.2MB/s]
# Done. Checkpoints are in /kaggle/working/IM-object-detection/IM-object-detection/saved_results/hgnet_ablation-retina-retina-hgnetv2_b4-h4_best_aug_sqrt_class_weight/checkpoints
# ============ Prediction Session ============
# image_source: public/val/images
# num_images: 1500
# output: val_predictions.json
# checkpoint: saved_results/hgnet_ablation-retina-retina-hgnetv2_b4-h4_best_aug_sqrt_class_weight/checkpoints/best_model.pth
# checkpoint_exists: True
# model_name: hgnet_ablation-retina-retina-hgnetv2_b4-h4_best_aug_sqrt_class_weight
# model_version: latest
# classes: ["person", "car", "dog", "cat", "chair"]
# device: cuda
# score_threshold: 0.0001
# nms_threshold: 0.4
# model: retina hgnetv2_b4
# custom_model: False
# model_impl: retina
# min_size: 640
# max_size: 960
# anchor_sizes: model_default
# anchor_ratios: model_default
# model_config_source: checkpoint
# ============================================
# Traceback (most recent call last):
#   File "/kaggle/working/IM-object-detection/IM-object-detection/predict.py", line 322, in <module>
#     main()
#   File "/kaggle/working/IM-object-detection/IM-object-detection/predict.py", line 305, in main
#     checkpoint = load_checkpoint(checkpoint_path, model, device)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/IM-object-detection/IM-object-detection/utils/helper.py", line 121, in load_checkpoint
#     model.load_state_dict(checkpoint["model_state_dict"])
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 2635, in load_state_dict
#     raise RuntimeError(
# RuntimeError: Error(s) in loading state_dict for RetinaNet:
# 	Unexpected key(s) in state_dict: "class_loss_weights".

# %%
# !python public/tools/evaluate_predictions.py \
  --ground_truth public/annotations/val.json \
  --predictions val_predictions.json \
  --output val_score.json
# Out:
# {
#   "mAP@0.5": 0.844803,
#   "performance_points": 20,
#   "iou_threshold": 0.5,
#   "num_ground_truth_boxes": 2021,
#   "num_predictions": 150000,
#   "micro_precision": 0.012807,
#   "micro_recall": 0.95052,
#   "per_class": {
#     "person": {
#       "ap": 0.891136,
#       "num_ground_truth": 1074,
#       "num_predictions": 41580,
#       "true_positives": 1030,
#       "false_positives": 40550,
#       "recall": 0.959032,
#       "precision": 0.024772
#     },
#     "car": {
#       "ap": 0.843754,
#       "num_ground_truth": 283,
#       "num_predictions": 28043,
#       "true_positives": 269,
#       "false_positives": 27774,
#       "recall": 0.95053,
#       "precision": 0.009592
#     },
#     "dog": {
#       "ap": 0.910923,
#       "num_ground_truth": 206,
#       "num_predictions": 21877,
#       "true_positives": 202,
#       "false_positives": 21675,
#       "recall": 0.980583,
#       "precision": 0.009233
#     },
#     "cat": {
#       "ap": 0.912743,
#       "num_ground_truth": 176,
#       "num_predictions": 21510,
#       "true_positives": 170,
#       "false_positives": 21340,
#       "recall": 0.965909,
#       "precision": 0.007903
#     },
#     "chair": {
#       "ap": 0.665459,
#       "num_ground_truth": 282,
#       "num_predictions": 36990,
#       "true_positives": 250,
#       "false_positives": 36740,
#       "recall": 0.886525,
#       "precision": 0.006759
#     }
#   }
# }

# %%
# !python predict.py \
    --image_dir ./public/test/images \
    --output test_predictions.json \
    --model_name $model_name
# Out:
# ============ Prediction Session ============
# image_source: public/test/images
# num_images: 12474
# output: test_predictions.json
# checkpoint: saved_results/hgnet_ablation-retina-retina-hgnetv2_b4-H3b_best_aug_class_small_balanced/checkpoints/best_model.pth
# checkpoint_exists: True
# model_name: hgnet_ablation-retina-retina-hgnetv2_b4-H3b_best_aug_class_small_balanced
# model_version: latest
# classes: ["person", "car", "dog", "cat", "chair"]
# device: cuda
# score_threshold: 0.0001
# nms_threshold: 0.4
# model: retina hgnetv2_b4
# custom_model: False
# model_impl: retina
# min_size: 640
# max_size: 960
# anchor_sizes: model_default
# anchor_ratios: model_default
# model_config_source: checkpoint
# ============================================
# predict:  46%|█████████████▍               | 5776/12474 [14:48<16:49,  6.63it/s]

# %%
# !python /kaggle/working/IM-object-detection/public/tools/convert.py \
--input test_predictions.json \
--output test_predictions.csv \
--classes /kaggle/working/IM-object-detection/public/classes.json

# %%
# !kaggle competitions submit -c from-scratch-object-detection-challenge -f test_predictions.csv  -m $model_name
