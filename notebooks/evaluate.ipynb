# %%
# !git clone https://github.com/ngocbao220/IM-object-detection.git
# Out:
# Cloning into 'IM-object-detection'...
# remote: Enumerating objects: 767, done.
# remote: Counting objects: 100% (372/372), done.
# remote: Compressing objects: 100% (242/242), done.
# remote: Total 767 (delta 166), reused 291 (delta 91), pack-reused 395 (from 1)
# Receiving objects: 100% (767/767), 52.39 MiB | 5.83 MiB/s, done.
# Resolving deltas: 100% (387/387), done.

# %%
# %cd IM-object-detection
# Out:
# /kaggle/working/IM-object-detection

# %%
# !git checkout retina-hgnetv2-b4-fpn
# Out:
# Branch 'retina-hgnetv2-b4-fpn' set up to track remote branch 'retina-hgnetv2-b4-fpn' from 'origin'.
# Switched to a new branch 'retina-hgnetv2-b4-fpn'

# %%
# !bash download.sh --dataset
# Out:
# ============ Download Kaggle Dataset ============
# dataset: ngocbaotrinhtuan/object-detection-public
# target: /kaggle/working/IM-object-detection
# =================================================
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.1), please consider upgrading to the latest version (2.0.2)
# Dataset URL: https://www.kaggle.com/datasets/ngocbaotrinhtuan/object-detection-public
# License(s): CC0-1.0
# Downloading object-detection-public.zip to /kaggle/working/IM-object-detection/.kaggle_download
# 100%|███████████████████████████████████████| 2.09G/2.09G [00:11<00:00, 198MB/s]
#
# Could not find public/ after dataset download under /kaggle/working/IM-object-detection/.kaggle_download

# %%
# !mv .kaggle_download public

# %%
# !python predict.py \
    --image_dir ./public/val/images \
    --output val_predictions.json \
    --model_name hgnet_ablation-retina-retina-hgnetv2_b4-h1_flip_color_scale_crop
# Out:
# Checkpoint not found; downloading from Kaggle Model...
# ============ Download Hugging Face Model ============
# repo_id: ngocbao05/object-detection-checkpoints
# path_in_repo: hgnet_ablation-retina-retina-hgnetv2_b4-h1_flip_color_scale_crop
# revision: main
# target: /kaggle/working/IM-object-detection/saved_results/hgnet_ablation-retina-retina-hgnetv2_b4-h1_flip_color_scale_crop/checkpoints
# =====================================================
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...):   0%|   | 303/173M [00:00<45:21:27, 1.06kB/s]
# Downloading (incomplete total...):   0%|   | 716/346M [00:00<46:19:00, 2.07kB/s]
# Downloading (incomplete total...): 100%|██████| 346M/346M [00:04<00:00, 117MB/s]
# Fetching 4 files: 100%|███████████████████████████| 4/4 [00:04<00:00,  1.08s/it]
# Download complete: 100%|██████████████████████| 346M/346M [00:04<00:00, 117MB/s]Downloaded ngocbao05/object-detection-checkpoints/hgnet_ablation-retina-retina-hgnetv2_b4-h1_flip_color_scale_crop to /kaggle/working/IM-object-detection/saved_results/.hf_model_download/hgnet_ablation-retina-retina-hgnetv2_b4-h1_flip_color_scale_crop
# Download complete: 100%|█████████████████████| 346M/346M [00:04<00:00, 79.6MB/s]
# Done. Checkpoints are in /kaggle/working/IM-object-detection/saved_results/hgnet_ablation-retina-retina-hgnetv2_b4-h1_flip_color_scale_crop/checkpoints
# ============ Prediction Session ============
# image_source: public/val/images
# num_images: 1500
# output: val_predictions.json
# checkpoint: saved_results/hgnet_ablation-retina-retina-hgnetv2_b4-h1_flip_color_scale_crop/checkpoints/best_model.pth
# checkpoint_exists: True
# model_name: hgnet_ablation-retina-retina-hgnetv2_b4-h1_flip_color_scale_crop
# model_version: latest
# classes: ["person", "car", "dog", "cat", "chair"]
# device: cuda
# score_threshold: 0.0001
# nms_threshold: 0.4
# model: retina hgnetv2_b4
# custom_model: False
# model_impl: retina
# min_size: 640
# max_size: 960
# anchor_sizes: model_default
# anchor_ratios: model_default
# model_config_source: checkpoint
# ============================================
# predict:  95%|████████████████████████████▌ | 1427/1500 [03:25<00:10,  6.69it/s]

# %%
# !python public/tools/evaluate_predictions.py \
  --ground_truth public/annotations/val.json \
  --predictions val_predictions.json \
  --output val_score.json

# %%
# !python predict.py \
    --image_dir ./public/test/images \
    --output test_predictions.json \
    --model_name hgnet_ablation-retina-retina-hgnetv2_b4-h1_flip_color_scale_crop

# %%
# !python /kaggle/working/IM-object-detection/public/tools/convert.py \
--input test_predictions.json \
--output test_predictions.csv \
--classes /kaggle/working/IM-object-detection/public/classes.json
